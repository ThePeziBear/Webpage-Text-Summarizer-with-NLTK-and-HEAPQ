# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup as bs
import requests
import nbimporter
from getFeed import parse_feed
# Out:
# Importing Jupyter notebook from getFeed.ipynb

# %%
test = parse_feed('https://www.cnbc.com/id/10000664/device/rss/rss.html')
test
# Out:
# {'feed': {'links': [{'rel': 'self',
#     'type': 'application/rss+xml',
#     'href': 'https://www.cnbc.com/id/10000664/device/rss/rss.html'},
#    {'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'https://www.cnbc.com/finance/'}],
#   'language': 'en-us',
#   'ttl': '60',
#   'title': 'Finance',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'https://www.cnbc.com/id/10000664/device/rss/rss.html',
#    'value': 'Finance'},
#   'id': 'https://www.cnbc.com/id/10000664/device/rss/10000664',
#   'guidislink': True,
#   'link': 'https://www.cnbc.com/finance/',
#   'type': 'franchise',
#   'subtype': 'section',
#   'seo': 'https://www.cnbc.com/finance/',
#   'feed_asset': '',
#   'updated': 'Sun, 19 Jan 2020 19:07 GMT',
#   'updated_parsed': time.struct_time(tm_year=2020, tm_mon=1, tm_mday=19, tm_hour=19, tm_min=7, tm_sec=0, tm_wday=6, tm_yday=19, tm_isdst=0),
#   'published': 'Sun, 19 Jan 2020 19:07 GMT',
# ...

# %%
test.keys()
# Out:
# dict_keys(['feed', 'entries', 'bozo', 'headers', 'href', 'status', 'encoding', 'version', 'namespaces'])

# %%
test.feed.subtitle_detail.value
# Out:
# 'Latest investing news and finance headlines straight from Wall Street.'

# %%
parse_feed(test.entries[1].link)
# Out:
# {'feed': {'html': {'lang': 'en',
#    'prefix': 'og=https://ogp.me/ns#',
#    'itemtype': 'https://schema.org/WebPage',
#    'class': ''},
#   'links': [{'rel': 'preload',
#     'as': 'font',
#     'href': 'https://static-redesign.cnbcfm.com/dist/icomoon.ttf',
#     'type': 'font/ttf',
#     'crossorigin': 'anonymous'},
#    {'rel': 'preload',
#     'as': 'font',
#     'href': 'https://static-redesign.cnbcfm.com/dist/351C86_0_0.woff2',
#     'type': 'font/woff2',
#     'crossorigin': 'anonymous'},
#    {'rel': 'preload',
#     'as': 'font',
#     'href': 'https://static-redesign.cnbcfm.com/dist/351C86_1_0.woff2',
#     'type': 'font/woff2',
#     'crossorigin': 'anonymous'},
#    {'rel': 'preload',
#     'as': 'font',
#     'href': 'https://static-redesign.cnbcfm.com/dist/351C86_2_0.woff2',
#     'type': 'font/woff2',
#     'crossorigin': 'anonymous'},
#    {'rel': 'preload',
#     'as': 'font',
#     'href': 'https://static-redesign.cnbcfm.com/dist/351C86_3_0.woff2',
# ...
